# %% [markdown]
# <a href="https://colab.research.google.com/github/amejiac/Alexis-Mejia-Cuevas/blob/master/Proyecto_1_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import missingno as msno
# %matplotlib inline

# %%
#https://www.kaggle.com/janiobachmann/math-students
path = 'student-mat.csv'
df = pd.read_csv(path, encoding='latin', error_bad_lines=False)
df.head()
# Out:
#   school sex  age address famsize Pstatus  ...  Walc  health absences  G1  G2  G3
# 0     GP   F   18       U     GT3       A  ...     1       3        6   5   6   6
# 1     GP   F   17       U     GT3       T  ...     1       3        4   5   5   6
# 2     GP   F   15       U     LE3       T  ...     3       3       10   7   8  10
# 3     GP   F   15       U     GT3       T  ...     1       5        2  15  14  15
# 4     GP   F   16       U     GT3       T  ...     2       5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
# school        395 non-null object
# sex           395 non-null object
# age           395 non-null int64
# address       395 non-null object
# famsize       395 non-null object
# Pstatus       395 non-null object
# Medu          395 non-null int64
# Fedu          395 non-null int64
# Mjob          395 non-null object
# Fjob          395 non-null object
# reason        395 non-null object
# guardian      395 non-null object
# traveltime    395 non-null int64
# studytime     395 non-null int64
# failures      395 non-null int64
# schoolsup     395 non-null object
# famsup        395 non-null object
# paid          395 non-null object
# activities    395 non-null object
# nursery       395 non-null object
# higher        395 non-null object
# internet      395 non-null object
# romantic      395 non-null object
# famrel        395 non-null int64
# ...

# %%
df.shape
# Out:
# (395, 33)

# %%
df.shape[0]
# Out:
# 395

# %%
df.shape[1]
# Out:
# 33

# %%
df.columns.values.tolist()
# Out:
# ['school',
#  'sex',
#  'age',
#  'address',
#  'famsize',
#  'Pstatus',
#  'Medu',
#  'Fedu',
#  'Mjob',
#  'Fjob',
#  'reason',
#  'guardian',
#  'traveltime',
#  'studytime',
#  'failures',
#  'schoolsup',
#  'famsup',
#  'paid',
#  'activities',
#  'nursery',
#  'higher',
#  'internet',
#  'romantic',
#  'famrel',
#  'freetime',
#  'goout',
#  'Dalc',
#  'Walc',
#  'health',
#  'absences',
#  'G1',
#  'G2',
#  'G3']

# %%
df.dtypes
# Out:
# school        object
# sex           object
# age            int64
# address       object
# famsize       object
# Pstatus       object
# Medu           int64
# Fedu           int64
# Mjob          object
# Fjob          object
# reason        object
# guardian      object
# traveltime     int64
# studytime      int64
# failures       int64
# schoolsup     object
# famsup        object
# paid          object
# activities    object
# nursery       object
# higher        object
# internet      object
# romantic      object
# famrel         int64
# freetime       int64
# goout          int64
# Dalc           int64
# Walc           int64
# health         int64
# absences       int64
# G1             int64
# G2             int64
# G3             int64
# dtype: object

# %%
df.isnull().any().any()
# Out:
# False

# %%
msno.matrix(df)

# %%
df.replace({' ': np.nan}, inplace=True)

# %%
df.isnull().any().any()
# Out:
# False

# %%
msno.matrix(df)

# %%
msno.bar(df)

# %%
df.columns[df.isnull().any()].tolist()
# Out:
# []

# %%
df.describe()
# Out:
#               age        Medu        Fedu  ...          G1          G2          G3
# count  395.000000  395.000000  395.000000  ...  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519  ...   10.908861   10.713924   10.415190
# std      1.276043    1.094735    1.088201  ...    3.319195    3.761505    4.581443
# min     15.000000    0.000000    0.000000  ...    3.000000    0.000000    0.000000
# 25%     16.000000    2.000000    2.000000  ...    8.000000    9.000000    8.000000
# 50%     17.000000    3.000000    2.000000  ...   11.000000   11.000000   11.000000
# 75%     18.000000    4.000000    3.000000  ...   13.000000   13.000000   14.000000
# max     22.000000    4.000000    4.000000  ...   19.000000   19.000000   20.000000
#
# [8 rows x 16 columns]

# %%
df.loc[[0]]
# Out:
#   school sex  age address famsize Pstatus  ...  Walc  health absences G1 G2 G3
# 0     GP   F   18       U     GT3       A  ...     1       3        6  5  6  6
#
# [1 rows x 33 columns]

# %%
df.loc[30:33]
# Out:
#    school sex  age address famsize Pstatus  ...  Walc  health absences  G1  G2  G3
# 30     GP   M   15       U     GT3       T  ...     4       5        0   9  11  12
# 31     GP   M   15       U     GT3       T  ...     1       5        0  17  16  17
# 32     GP   M   15       R     GT3       T  ...     1       5        0  17  16  16
# 33     GP   M   15       U     LE3       T  ...     1       2        0   8  10  12
#
# [4 rows x 33 columns]

# %%
df.drop([0,24,51], axis=0).head()
# Out:
#   school sex  age address famsize Pstatus  ...  Walc  health absences  G1  G2  G3
# 1     GP   F   17       U     GT3       T  ...     1       3        4   5   5   6
# 2     GP   F   15       U     LE3       T  ...     3       3       10   7   8  10
# 3     GP   F   15       U     GT3       T  ...     1       5        2  15  14  15
# 4     GP   F   16       U     GT3       T  ...     2       5        4   6  10  10
# 5     GP   M   16       U     LE3       T  ...     2       5       10  15  15  15
#
# [5 rows x 33 columns]

# %%
  df.drop(df.index[1:5], axis=0).head(10)
# Out:
#    school sex  age address famsize Pstatus  ...  Walc  health absences  G1  G2  G3
# 0      GP   F   18       U     GT3       A  ...     1       3        6   5   6   6
# 5      GP   M   16       U     LE3       T  ...     2       5       10  15  15  15
# 6      GP   M   16       U     LE3       T  ...     1       3        0  12  12  11
# 7      GP   F   17       U     GT3       A  ...     1       1        6   6   5   6
# 8      GP   M   15       U     LE3       A  ...     1       1        0  16  18  19
# 9      GP   M   15       U     GT3       T  ...     1       5        0  14  15  15
# 10     GP   F   15       U     GT3       T  ...     2       2        0  10   8   9
# 11     GP   F   15       U     GT3       T  ...     1       4        4  10  12  12
# 12     GP   M   15       U     LE3       T  ...     3       5        2  14  14  14
# 13     GP   M   15       U     GT3       T  ...     2       3        2  10  10  11
#
# [10 rows x 33 columns]

# %%
df[100:].head() #df.tail(-100) )
# Out:
#     school sex  age address famsize Pstatus  ...  Walc  health absences  G1  G2  G3
# 100     GP   M   16       U     GT3       T  ...     5       4       14   7   7   5
# 101     GP   M   16       U     GT3       T  ...     1       4        0  16  17  17
# 102     GP   M   15       U     GT3       T  ...     1       5        4  10  13  14
# 103     GP   F   15       U     GT3       T  ...     1       2       26   7   6   6
# 104     GP   M   15       U     GT3       A  ...     1       1        0  16  18  18
#
# [5 rows x 33 columns]

# %%
df.G3.values
# Out:
# array([ 6,  6, 10, 15, 10, 15, 11,  6, 19, 15,  9, 12, 14, 11, 16, 14, 14,
#        10,  5, 10, 15, 15, 16, 12,  8,  8, 11, 15, 11, 11, 12, 17, 16, 12,
#        15,  6, 18, 15, 11, 13, 11, 12, 18, 11,  9,  6, 11, 20, 14,  7, 13,
#        13, 10, 11, 13, 10, 15, 15,  9, 16, 11, 11,  9,  9, 10, 15, 12,  6,
#         8, 16, 15, 10,  5, 14, 11, 10, 10, 11, 10,  5, 12, 11,  6, 15, 10,
#         8,  6, 14, 10,  7,  8, 18,  6, 10, 14, 10, 15, 10, 14,  8,  5, 17,
#        14,  6, 18, 11,  8, 18, 13, 16, 19, 10, 13, 19,  9, 16, 14, 13,  8,
#        13, 15, 15, 13, 13,  8, 12, 11,  9,  0, 18,  0,  0, 12, 11,  0,  0,
#         0,  0, 12, 15,  0,  9, 11, 13,  0, 11,  0, 11,  0, 10,  0, 14, 10,
#         0, 12,  8, 13, 10, 15, 12,  0,  7,  0, 10,  7, 12, 10, 16,  0, 14,
#         0, 16, 10,  0,  9,  9, 11,  6,  9, 11,  8, 12, 17,  8, 12, 11, 11,
#        15,  9, 10, 13,  9,  8, 10, 14, 15, 16, 10, 18, 10, 16, 10, 10,  6,
# ...

# %%
df['G3'].values
# Out:
# array([ 6,  6, 10, 15, 10, 15, 11,  6, 19, 15,  9, 12, 14, 11, 16, 14, 14,
#        10,  5, 10, 15, 15, 16, 12,  8,  8, 11, 15, 11, 11, 12, 17, 16, 12,
#        15,  6, 18, 15, 11, 13, 11, 12, 18, 11,  9,  6, 11, 20, 14,  7, 13,
#        13, 10, 11, 13, 10, 15, 15,  9, 16, 11, 11,  9,  9, 10, 15, 12,  6,
#         8, 16, 15, 10,  5, 14, 11, 10, 10, 11, 10,  5, 12, 11,  6, 15, 10,
#         8,  6, 14, 10,  7,  8, 18,  6, 10, 14, 10, 15, 10, 14,  8,  5, 17,
#        14,  6, 18, 11,  8, 18, 13, 16, 19, 10, 13, 19,  9, 16, 14, 13,  8,
#        13, 15, 15, 13, 13,  8, 12, 11,  9,  0, 18,  0,  0, 12, 11,  0,  0,
#         0,  0, 12, 15,  0,  9, 11, 13,  0, 11,  0, 11,  0, 10,  0, 14, 10,
#         0, 12,  8, 13, 10, 15, 12,  0,  7,  0, 10,  7, 12, 10, 16,  0, 14,
#         0, 16, 10,  0,  9,  9, 11,  6,  9, 11,  8, 12, 17,  8, 12, 11, 11,
#        15,  9, 10, 13,  9,  8, 10, 14, 15, 16, 10, 18, 10, 16, 10, 10,  6,
# ...

# %%
df.G3.unique()
# Out:
# array([ 6, 10, 15, 11, 19,  9, 12, 14, 16,  5,  8, 17, 18, 13, 20,  7,  0,
#         4])

# %%
df.G3.value_counts()
# Out:
# 10    56
# 11    47
# 0     38
# 15    33
# 8     32
# 13    31
# 12    31
# 9     28
# 14    27
# 16    16
# 6     15
# 18    12
# 7      9
# 5      7
# 17     6
# 19     5
# 4      1
# 20     1
# Name: G3, dtype: int64

# %%
df.agg(['count', 'size', 'nunique'])
# Out:
#          school  sex  age  address  famsize  ...  health  absences   G1   G2   G3
# count       395  395  395      395      395  ...     395       395  395  395  395
# size        395  395  395      395      395  ...     395       395  395  395  395
# nunique       2    2    8        2        2  ...       5        34   17   17   18
#
# [3 rows x 33 columns]

# %%
df.groupby('studytime').agg(['count', 'size', 'nunique']).stack()
# Out:
#                    school  sex  age  address  ...  absences   G1   G2   G3
# studytime                                     ...
# 1         count       105  105  105      105  ...       105  105  105  105
#           size        105  105  105      105  ...       105  105  105  105
#           nunique       2    2    8        2  ...        19   15   17   15
# 2         count       198  198  198      198  ...       198  198  198  198
#           size        198  198  198      198  ...       198  198  198  198
#           nunique       2    2    6        2  ...        26   15   15   17
# 3         count        65   65   65       65  ...        65   65   65   65
#           size         65   65   65       65  ...        65   65   65   65
#           nunique       2    2    6        2  ...        16   13   14   14
# 4         count        27   27   27       27  ...        27   27   27   27
#           size         27   27   27       27  ...        27   27   27   27
# ...

# %%
df.groupby('studytime').agg(['count', 'size', 'nunique'])
# Out:
#           school                sex       ...   G2            G3
#            count size nunique count size  ... size nunique count size nunique
# studytime                                 ...
# 1            105  105       2   105  105  ...  105      17   105  105      15
# 2            198  198       2   198  198  ...  198      15   198  198      17
# 3             65   65       2    65   65  ...   65      14    65   65      14
# 4             27   27       1    27   27  ...   27      13    27   27      13
#
# [4 rows x 96 columns]

# %%
df_sample = df.sample(frac=0.05, random_state=1)
df_sample.head()
# Out:
#     school sex  age address famsize Pstatus  ...  Walc  health absences  G1  G2  G3
# 146     GP   F   15       U     GT3       T  ...     1       3        0   6   7   0
# 379     MS   F   17       R     GT3       T  ...     3       1       17  10  10  10
# 247     GP   M   22       U     GT3       T  ...     5       1       16   6   8   8
# 197     GP   M   16       R     LE3       T  ...     5       3        8   9   9  10
# 368     MS   F   18       U     GT3       T  ...     2       4        0  11  10  10
#
# [5 rows x 33 columns]

# %%
df.shape
# Out:
# (395, 33)

# %%
df_sample.shape
# Out:
# (20, 33)

# %%
df_dropped = df.dropna(subset=['G1'])
df_dropped.head()
# Out:
#   school sex  age address famsize Pstatus  ...  Walc  health absences  G1  G2  G3
# 0     GP   F   18       U     GT3       A  ...     1       3        6   5   6   6
# 1     GP   F   17       U     GT3       T  ...     1       3        4   5   5   6
# 2     GP   F   15       U     LE3       T  ...     3       3       10   7   8  10
# 3     GP   F   15       U     GT3       T  ...     1       5        2  15  14  15
# 4     GP   F   16       U     GT3       T  ...     2       5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
df_dropped.shape
# Out:
# (395, 33)

# %%
df_copy = df.copy()
df_copy.head()
# Out:
#   school sex  age address famsize Pstatus  ...  Walc  health absences  G1  G2  G3
# 0     GP   F   18       U     GT3       A  ...     1       3        6   5   6   6
# 1     GP   F   17       U     GT3       T  ...     1       3        4   5   5   6
# 2     GP   F   15       U     LE3       T  ...     3       3       10   7   8  10
# 3     GP   F   15       U     GT3       T  ...     1       5        2  15  14  15
# 4     GP   F   16       U     GT3       T  ...     2       5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
df_copy.shape
# Out:
# (395, 33)

# %%
df_dropped['G3'].dtype
# Out:
# dtype('int64')

# %%
df_dropped['G3'].mean()
# Out:
# 10.415189873417722

# %%
df_copy['G3'].fillna(value=np.round(df['G3'].mean(),decimals=0), inplace=True)

# %%
df_copy.agg(['count', 'size', 'nunique'])
# Out:
#          school  sex  age  address  famsize  ...  health  absences   G1   G2   G3
# count       395  395  395      395      395  ...     395       395  395  395  395
# size        395  395  395      395      395  ...     395       395  395  395  395
# nunique       2    2    8        2        2  ...       5        34   17   17   18
#
# [3 rows x 33 columns]

# %%
list(df['studytime'].unique())
# Out:
# [2, 3, 1, 4]

# %%
df['studytime'].replace({1:"ningun dia", 
                       2:"1-2 dias a la semana",
                       3:"3-4 dias a la semana",  
                       4:"5-6 dias a la semana"}, inplace=True)

# %%
list(df['studytime'].unique())
# Out:
# ['1-2 dias a la semana',
#  '3-4 dias a la semana',
#  'ningun dia',
#  '5-6 dias a la semana']

# %%
keys = list(df['studytime'].unique())
vals = range(1,8)
act = dict(zip(keys, vals))
act
# Out:
# {'1-2 dias a la semana': 1,
#  '3-4 dias a la semana': 2,
#  '5-6 dias a la semana': 4,
#  'ningun dia': 3}

# %%
df_copy['studytime_cat'] = df['studytime'].map(act)
df_copy.head()
# Out:
#   school sex  age address famsize  ... absences  G1  G2  G3 studytime_cat
# 0     GP   F   18       U     GT3  ...        6   5   6   6             1
# 1     GP   F   17       U     GT3  ...        4   5   5   6             1
# 2     GP   F   15       U     LE3  ...       10   7   8  10             1
# 3     GP   F   15       U     GT3  ...        2  15  14  15             2
# 4     GP   F   16       U     GT3  ...        4   6  10  10             1
#
# [5 rows x 34 columns]

# %%
list(df_copy['studytime_cat'].unique())
# Out:
# [1, 2, 3, 4]

# %%
df_copy['G3'].mean()
# Out:
# 10.415189873417722

# %%
df_copy['G3'][df_copy['studytime']]
# Out:
# 2    10
# 2    10
# 2    10
# 3    15
# 2    10
#      ..
# 2    10
# 1     6
# 1     6
# 1     6
# 1     6
# Name: G3, Length: 395, dtype: int64

# %%
df_copy['G3'][df_copy['studytime_cat']].mean()
# Out:
# 9.324050632911392

# %%
df_copy.groupby(["studytime_cat", "traveltime", "freetime", "internet"]).count()
# Out:
#                                             school  sex  age  ...  G1  G2  G3
# studytime_cat traveltime freetime internet                    ...
# 1             1          1        no             2    2    2  ...   2   2   2
#                                   yes            4    4    4  ...   4   4   4
#                          2        no             3    3    3  ...   3   3   3
#                                   yes           16   16   16  ...  16  16  16
#                          3        no             6    6    6  ...   6   6   6
# ...                                            ...  ...  ...  ...  ..  ..  ..
# 4             2          2        yes            1    1    1  ...   1   1   1
#                          3        yes            2    2    2  ...   2   2   2
#                          4        no             1    1    1  ...   1   1   1
#                                   yes            2    2    2  ...   2   2   2
# ...

# %%
df_copy.groupby(["studytime_cat", "traveltime", "freetime", "internet"]).count()
# Out:
#                                             school  sex  age  ...  G1  G2  G3
# studytime_cat traveltime freetime internet                    ...
# 1             1          1        no             2    2    2  ...   2   2   2
#                                   yes            4    4    4  ...   4   4   4
#                          2        no             3    3    3  ...   3   3   3
#                                   yes           16   16   16  ...  16  16  16
#                          3        no             6    6    6  ...   6   6   6
# ...                                            ...  ...  ...  ...  ..  ..  ..
# 4             2          2        yes            1    1    1  ...   1   1   1
#                          3        yes            2    2    2  ...   2   2   2
#                          4        no             1    1    1  ...   1   1   1
#                                   yes            2    2    2  ...   2   2   2
# ...

# %%
df_copy.groupby(["studytime", "traveltime"])[["freetime", "internet"]].count()
# Out:
#                       freetime  internet
# studytime traveltime
# 1         1                 60        60
#           2                 31        31
#           3                 11        11
#           4                  3         3
# 2         1                133       133
#           2                 51        51
#           3                 11        11
#           4                  3         3
# 3         1                 47        47
#           2                 16        16
#           3                  1         1
#           4                  1         1
# 4         1                 17        17
#           2                  9         9
#           4                  1         1

# %%
df_copy.studytime
# Out:
# 0      2
# 1      2
# 2      2
# 3      3
# 4      2
#       ..
# 390    2
# 391    1
# 392    1
# 393    1
# 394    1
# Name: studytime, Length: 395, dtype: int64

# %%
df_sample = df.sample(frac=0.05, random_state=1)
df_sample.head()
# Out:
#     school sex  age address famsize Pstatus  ...  Walc  health absences  G1  G2  G3
# 146     GP   F   15       U     GT3       T  ...     1       3        0   6   7   0
# 379     MS   F   17       R     GT3       T  ...     3       1       17  10  10  10
# 247     GP   M   22       U     GT3       T  ...     5       1       16   6   8   8
# 197     GP   M   16       R     LE3       T  ...     5       3        8   9   9  10
# 368     MS   F   18       U     GT3       T  ...     2       4        0  11  10  10
#
# [5 rows x 33 columns]

# %%
# variant-1: multiple aggregations on single attribute
df_sample.groupby(["studytime", "traveltime"])[["freetime", "internet"]].agg([np.sum, np.mean,
                                                              np.count_nonzero])
# Out:
#                                 freetime
#                                      sum      mean count_nonzero
# studytime            traveltime
# 1-2 dias a la semana 1                28  4.000000             7
#                      2                11  3.666667             3
#                      3                 2  2.000000             1
# 3-4 dias a la semana 1                 3  3.000000             1
# 5-6 dias a la semana 1                 5  5.000000             1
# ningun dia           1                11  3.666667             3
#                      2                11  3.666667             3
#                      3                 3  3.000000             1

# %%
# variant-2: different aggregation functions for each attribute 

df_sample.groupby(["studytime", "traveltime"]).agg({'G3':np.mean,'internet':np.max})
# Out:
#                                         G3 internet
# studytime            traveltime
# 1-2 dias a la semana 1            9.142857      yes
#                      2            9.000000      yes
#                      3           11.000000      yes
# 3-4 dias a la semana 1            8.000000      yes
# 5-6 dias a la semana 1            8.000000      yes
# ningun dia           1           10.000000      yes
#                      2           12.666667      yes
#                      3           10.000000      yes

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')

ax1 = plt.axes()  # standard axes
ax2 = plt.axes([0.65, 0.65, 0.2, 0.2])

# %%
#The equivalent of this command within the object-oriented interface is fig.add_axes()

fig = plt.figure()
ax1 = fig.add_axes([0.1, 0.5, 0.8, 0.4],
                   xticklabels=[], ylim=(-1.2, 1.2))
ax2 = fig.add_axes([0.1, 0.1, 0.8, 0.4],
                   ylim=(-1.2, 1.2))

x = np.linspace(0, 10)
ax1.plot(np.sin(x))
ax2.plot(np.cos(x))

# %%
# The lowest level of these is plt.subplot(), which creates a single subplot within a grid
for i in range(1, 7):
    plt.subplot(2, 3, i)
    plt.text(0.5, 0.5, str((2, 3, i)),
             fontsize=18, ha='center')

# %%
# plt.subplots_adjust can be used to adjust the spacing between these plots
fig = plt.figure()
fig.subplots_adjust(hspace=0.4, wspace=0.4)
for i in range(1, 7):
    ax = fig.add_subplot(2, 3, i)
    ax.text(0.5, 0.5, str((2, 3, i)),
           fontsize=18, ha='center')

# %%
fig, ax = plt.subplots(2, 3, sharex='col', sharey='row')

# %%
# axes are in a two-dimensional array, indexed by [row, col]
for i in range(2):
    for j in range(3):
        ax[i, j].text(0.5, 0.5, str((i, j)),
                      fontsize=18, ha='center')
fig

# %%
mean = [0, 0]
cov = [[1, 1], [1, 2]]
x, y = np.random.multivariate_normal(mean, cov, 3000).T

# Set up the axes with gridspec
fig = plt.figure(figsize=(6, 6))
grid = plt.GridSpec(4, 4, hspace=0.2, wspace=0.2)
main_ax = fig.add_subplot(grid[:-1, 1:])
y_hist = fig.add_subplot(grid[:-1, 0], xticklabels=[], sharey=main_ax)
x_hist = fig.add_subplot(grid[-1, 1:], yticklabels=[], sharex=main_ax)

# scatter points on the main axes
main_ax.plot(x, y, 'ok', markersize=3, alpha=0.2)

# histogram on the attached axes
x_hist.hist(x, 40, histtype='stepfilled',
            orientation='vertical', color='gray')
x_hist.invert_yaxis()

y_hist.hist(y, 40, histtype='stepfilled',
            orientation='horizontal', color='gray')
y_hist.invert_xaxis()

# %%
#figure.savefig('.../.jpeg')
#df_sample['ventas'] = dropna()
df_sample['G3'] = df_sample['G3'].astype('int64')

df_sample.plot(kind='scatter',x='G3',y='studytime')

# %%
plt.hist(df_sample['studytime'])
plt.xlabel('studytime')
plt.ylabel('Frequency')
plt.title('Frequency of study time')
# Out:
# Text(0.5, 1.0, 'Frequency of study time')

# %%
plt.hist(df_sample['G3'])
plt.xlabel('FINAL GRADES')
plt.ylabel('Frequency')
plt.title('Frequency of FINAL GRADES')
# Out:
# Text(0.5, 1.0, 'Frequency of FINAL GRADES')

# %%
plt.boxplot(df_sample['G3'], showmeans=True, meanline=True)
plt.ylabel('Final Grades count')
plt.title('Box Plot of ventas count')
# Out:
# Text(0.5, 1.0, 'Box Plot of ventas count')
